# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalJagielo/DataScience_ExercisesPractice_Python/blob/main/02_pandas_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### Case Study I

import pandas as pd
import numpy as np
print(f"Numpy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
# Out:
# Numpy: 1.19.5
# Pandas: 1.1.5

# %%
def fetch_financial_data(company='AMZN'):
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
# df.info()
# print(df.head(3))
# print(df.tail(3))
df.columns = [col.lower() for col in df.columns]
df

# %%
df.describe().T

# %%
df = df.head(10)
df
# Out:
#                open      high        low    close   volume
# Date
# 2022-01-11  3230.00  3327.000  3214.0300  3307.24  3140279
# 2022-01-10  3211.71  3233.230  3126.0900  3229.72  4389915
# 2022-01-07  3276.78  3304.865  3240.6200  3251.08  2330295
# 2022-01-06  3269.01  3296.000  3238.7442  3265.08  2597889
# 2022-01-05  3337.66  3342.525  3287.1400  3287.14  3215136
# 2022-01-04  3408.76  3428.000  3326.9900  3350.44  3536258
# 2022-01-03  3351.00  3414.070  3323.2100  3408.09  3193457
# 2021-12-31  3379.12  3387.000  3331.1700  3334.34  2391519
# 2021-12-30  3394.00  3417.760  3370.4800  3372.89  1879155
# 2021-12-29  3416.80  3424.240  3372.0101  3384.02  1787702

# %%
df[['open', 'close']]
# Out:
#                open    close
# Date
# 2022-01-11  3230.00  3307.24
# 2022-01-10  3211.71  3229.72
# 2022-01-07  3276.78  3251.08
# 2022-01-06  3269.01  3265.08
# 2022-01-05  3337.66  3287.14
# 2022-01-04  3408.76  3350.44
# 2022-01-03  3351.00  3408.09
# 2021-12-31  3379.12  3334.34
# 2021-12-30  3394.00  3372.89
# 2021-12-29  3416.80  3384.02

# %%
df.iloc[:,[0,3]]
# Out:
#                open    close
# Date
# 2022-01-11  3230.00  3307.24
# 2022-01-10  3211.71  3229.72
# 2022-01-07  3276.78  3251.08
# 2022-01-06  3269.01  3265.08
# 2022-01-05  3337.66  3287.14
# 2022-01-04  3408.76  3350.44
# 2022-01-03  3351.00  3408.09
# 2021-12-31  3379.12  3334.34
# 2021-12-30  3394.00  3372.89
# 2021-12-29  3416.80  3384.02

# %%
df.iloc[:, 3:5]
df.iloc[:, [-1]]

# %%
df.iloc[:3]
# Out:
#                open      high      low    close   volume
# Date
# 2022-01-11  3230.00  3327.000  3214.03  3307.24  3140279
# 2022-01-10  3211.71  3233.230  3126.09  3229.72  4389915
# 2022-01-07  3276.78  3304.865  3240.62  3251.08  2330295

# %%
df.loc['2022-01-11':'2022-01-06']
df.iloc[0:4]
# Out:
#                open      high        low    close   volume
# Date
# 2022-01-11  3230.00  3327.000  3214.0300  3307.24  3140279
# 2022-01-10  3211.71  3233.230  3126.0900  3229.72  4389915
# 2022-01-07  3276.78  3304.865  3240.6200  3251.08  2330295
# 2022-01-06  3269.01  3296.000  3238.7442  3265.08  2597889

# %%
df = fetch_financial_data('MSFT')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2022-01-11 to 2017-01-13
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1258 non-null   float64
#  1   High    1258 non-null   float64
#  2   Low     1258 non-null   float64
#  3   Close   1258 non-null   float64
#  4   Volume  1258 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB
#                Open     High      Low    Close    Volume
# Date
# 2022-01-11  313.380  316.610  309.890  314.980  29386774
# 2022-01-10  309.485  314.720  304.690  314.270  44289467
# 2022-01-07  314.150  316.500  310.090  314.040  32720018
# 2022-01-06  313.150  318.700  311.490  313.880  39646148
# 2022-01-05  325.860  326.070  315.980  316.380  40054327
# ...             ...      ...      ...      ...       ...
# 2017-01-20   58.377   58.515   58.098   58.439  29307090
# 2017-01-19   57.974   58.663   57.933   58.031  19447907
# ...

# %%
df = fetch_financial_data('UBER')
# df.info()
df.describe()
df.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2022-01-11  42.36  44.17  42.19  43.62  22160976
# 2022-01-10  41.48  42.81  40.16  42.60  29783757
# 2022-01-07  42.00  42.65  41.20  41.51  24875831
# 2022-01-06  43.11  44.08  40.97  42.03  32434252
# 2022-01-05  44.29  45.90  42.86  43.24  28498663

# %%
df['Average'] = (df.Open + df.Close) / 2
df

# %%
df['Close_shift'] = df[['Close']].shift(1)
df.head()
# Out:
#              Open   High    Low  ...     PCT   PCT %  Close_shift
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ... -0.8457 -0.8457          NaN
# 2019-05-13  38.79  39.24  36.08  ... -2.0610 -2.0610        41.57
# 2019-05-14  38.31  39.96  36.85  ...  1.2504  1.2504        37.10
# 2019-05-15  39.37  41.88  38.95  ...  1.5071  1.5071        39.96
# 2019-05-16  41.48  44.06  41.25  ...  1.0900  1.0900        41.29
#
# [5 rows x 10 columns]

# %%
df['Pct'] = round(((df.Close - df.Open)/df.Close)*100, 2)
df
# Out:
#              Open   High    Low  Close  ...  Average  Close_shift  Daily_chage   Pct
# Date                                    ...
# 2019-05-10  42.00  45.00  41.06  41.57  ...   41.785          NaN          NaN -1.03
# 2019-05-13  38.79  39.24  36.08  37.10  ...   37.945        41.57    -0.107529 -4.56
# 2019-05-14  38.31  39.96  36.85  39.96  ...   39.135        37.10     0.077089  4.13
# 2019-05-15  39.37  41.88  38.95  41.29  ...   40.330        39.96     0.033283  4.65
# 2019-05-16  41.48  44.06  41.25  43.00  ...   42.240        41.29     0.041414  3.53
#
# [5 rows x 9 columns]

# %%
df['Daily_chage'] = (df.Close / df.Close_shift - 1)
df.Daily_chage.max()
df.head()
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_chage
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN          NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57    -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10     0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96     0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29     0.041414
#
# [5 rows x 8 columns]

# %%
# Out:
#              Open   High    Low  ...  Average  Close_shift  Daily_chage
# Date                             ...
# 2019-05-10  42.00  45.00  41.06  ...   41.785          NaN          NaN
# 2019-05-13  38.79  39.24  36.08  ...   37.945        41.57    -0.107529
# 2019-05-14  38.31  39.96  36.85  ...   39.135        37.10     0.077089
# 2019-05-15  39.37  41.88  38.95  ...   40.330        39.96     0.033283
# 2019-05-16  41.48  44.06  41.25  ...   42.240        41.29     0.041414
#
# [5 rows x 8 columns]

# %%
df = fetch_financial_data('UBER')
df
df['Close_shift'] = df[['Close']].shift(1)
df['Average'] = (df.Open + df.Close) / 2
df['Daily_chage'] = (df.Close / df.Close_shift - 1)
df
# Out:
#              Open   High    Low  ...  Close_shift  Average  Daily_chage
# Date                             ...
# 2022-01-11  42.36  44.17  42.19  ...          NaN   42.990          NaN
# 2022-01-10  41.48  42.81  40.16  ...        43.62   42.040    -0.023384
# 2022-01-07  42.00  42.65  41.20  ...        42.60   41.755    -0.025587
# 2022-01-06  43.11  44.08  40.97  ...        41.51   42.570     0.012527
# 2022-01-05  44.29  45.90  42.86  ...        42.03   43.765     0.028789
# ...           ...    ...    ...  ...          ...      ...          ...
# 2019-05-16  41.48  44.06  41.25  ...        41.91   42.240     0.026008
# 2019-05-15  39.37  41.88  38.95  ...        43.00   40.330    -0.039767
# 2019-05-14  38.31  39.96  36.85  ...        41.29   39.135    -0.032211
# 2019-05-13  38.79  39.24  36.08  ...        39.96   37.945    -0.071572
# 2019-05-10  42.00  45.00  41.06  ...        37.10   41.785     0.120485
#
# [675 rows x 8 columns]

# %%
import seaborn as sns
sns.set()

df.Daily_chage.hist(bins=100)

# %%
df.Close.plot()

# %%
ndf = df[:500]
ndf.Daily_chage.hist(bins=100)
#ndf.Close.plot()

# %%
df.Close.plot()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 675 entries, 2022-01-11 to 2019-05-10
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         675 non-null    float64
#  1   High         675 non-null    float64
#  2   Low          675 non-null    float64
#  3   Close        675 non-null    float64
#  4   Volume       675 non-null    int64
#  5   Close_shift  674 non-null    float64
#  6   Average      675 non-null    float64
#  7   Daily_chage  674 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 47.5 KB
